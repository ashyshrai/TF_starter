# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,Conv2D,MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

# %%
X=pickle.load(open('X.pickle','rb'))
y=pickle.load(open('y.pickle','rb'))

#normalize
X=X/255.0

# %%
X.shape
# Out:
# (24946, 100, 100, 1)

# %%
X.shape[1:]
# Out:
# (100, 100, 1)

# %%
X=np.array(X)
y=np.array(y)

# %%
#Call backs
NAME="Cats-vs-Dog-cnn-64*2-{}".format(int(time.time()))
tensorboard_callback=TensorBoard(log_dir='cat_dog_tensorboard_log/{}'.format(NAME))

# %%
model=Sequential()
model.add(Conv2D(64,(3,3),input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#flatten from 2D to 1D
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))

#output layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

#compile
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics='accuracy')

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 98, 98, 64)        640
# _________________________________________________________________
# activation_13 (Activation)   (None, 98, 98, 64)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 47, 47, 64)        36928
# _________________________________________________________________
# activation_14 (Activation)   (None, 47, 47, 64)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 33856)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                2166848
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_15 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 2,204,481
# Trainable params: 2,204,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X,y,
          batch_size=64,
          epochs=10,
          validation_split=0.2,
          callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
# 312/312 [==============================] - 150s 479ms/step - loss: 0.4372 - accuracy: 0.7998 - val_loss: 0.5430 - val_accuracy: 0.7419
# Epoch 2/10
# 312/312 [==============================] - 165s 529ms/step - loss: 0.4028 - accuracy: 0.8174 - val_loss: 0.4851 - val_accuracy: 0.7782
# Epoch 3/10
# 312/312 [==============================] - 166s 533ms/step - loss: 0.3636 - accuracy: 0.8374 - val_loss: 0.5290 - val_accuracy: 0.7605
# Epoch 4/10
# 312/312 [==============================] - 171s 549ms/step - loss: 0.3332 - accuracy: 0.8515 - val_loss: 0.5149 - val_accuracy: 0.7790
# Epoch 5/10
# 312/312 [==============================] - 170s 545ms/step - loss: 0.2971 - accuracy: 0.8711 - val_loss: 0.5446 - val_accuracy: 0.7733
# Epoch 6/10
# 312/312 [==============================] - 169s 543ms/step - loss: 0.2578 - accuracy: 0.8909 - val_loss: 0.5934 - val_accuracy: 0.7725
# Epoch 7/10
# 312/312 [==============================] - 169s 542ms/step - loss: 0.2229 - accuracy: 0.9054 - val_loss: 0.6954 - val_accuracy: 0.7613
# Epoch 8/10
# 312/312 [==============================] - 172s 551ms/step - loss: 0.1924 - accuracy: 0.9186 - val_loss: 0.7329 - val_accuracy: 0.7693
# Epoch 9/10
# 312/312 [==============================] - 171s 549ms/step - loss: 0.1671 - accuracy: 0.9304 - val_loss: 0.8671 - val_accuracy: 0.7581
# Epoch 10/10
# 167/312 [===============>..............] - ETA: 1:09 - loss: 0.1304 - accuracy: 0.9491
